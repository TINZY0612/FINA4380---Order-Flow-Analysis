# %%
import pandas as pd

# %%
df = pd.read_csv("preprocessed_factors.csv")
df.head()
# Out:
#       timestamp   symbol  bid_1_p  bid_1_s  bid_2_p   bid_2_s  bid_3_p  \
# 0  1.773300e+09  ADAUSDT   0.2593  97483.5   0.2592  171093.0   0.2591
# 1  1.773300e+09  ADAUSDT   0.2593  97483.5   0.2592  171093.0   0.2591
# 2  1.773300e+09  ADAUSDT   0.2593  97483.5   0.2592  171093.0   0.2591
# 3  1.773300e+09  ADAUSDT   0.2593  95965.2   0.2592  171093.0   0.2591
# 4  1.773300e+09  ADAUSDT   0.2593  88947.1   0.2592  171093.0   0.2591
#
#     bid_3_s  bid_4_p   bid_4_s  ...  ask_6_p   ask_6_s  ask_7_p   ask_7_s  \
# 0  218187.2    0.259  281449.9  ...   0.2599  165753.2     0.26  278159.3
# 1  218187.2    0.259  281449.9  ...   0.2599  165753.2     0.26  278159.3
# 2  218187.2    0.259  281449.9  ...   0.2599  165753.2     0.26  278159.3
# 3  218187.2    0.259  281449.9  ...   0.2599  165753.2     0.26  278159.3
# 4  218187.2    0.259  281449.9  ...   0.2599  165753.2     0.26  278159.3
#
#    ask_8_p   ask_8_s  ask_9_p   ask_9_s  ask_10_p  ask_10_s
# ...

# %%
df.groupby("symbol").size()
# Out:
# symbol
# ADAUSDT     2990
# AVAXUSDT    2990
# BNBUSDT     2990
# BTCUSDT     2990
# DOGEUSDT    2990
# DOTUSDT     2990
# ETHUSDT     2990
# SOLUSDT     2990
# XRPUSDT     2990
# dtype: int64
